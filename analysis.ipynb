# %%
import pandas as pd
import numpy as np
import re
import plotly.express as px
import plotly.io as pio
from math import floor, ceil

pio.renderers.default = "notebook_connected"

# %%
df = pd.read_json('runs2.json')

descriptions = {
    'matMulStd': 'Standard (No Vectorization)',
    'matMulVec': 'Vectorized By Compiler',
    'matMulIntr': 'Vectorized With Intrinsics'
}

df['description'] = df['binary'].map(descriptions)

list_cols = [col for col in df.columns if df[col].dtype == 'object' and df[col].apply(lambda x: isinstance(x, list)).all()]

df = df.drop(list_cols, axis=1)

df = df.drop(['meanCacheMisses', 'meanCacheReferences', 'meanCacheMissRate'], axis=1)

df
# Out:
#         binary  runArg    meanTime  meanL1CacheLoadMisses  meanL1CacheLoads  \
# 0    matMulStd      10    0.000863           2.481500e+03      4.165250e+04
# 1    matMulVec      10    0.000768           2.547300e+03      4.078250e+04
# 2   matMulIntr      10    0.000734           2.495700e+03      4.046520e+04
# 3    matMulStd      25    0.000919           2.672000e+03      9.562360e+04
# 4    matMulVec      25    0.000745           2.688000e+03      8.136860e+04
# 5   matMulIntr      25    0.000805           2.658200e+03      7.316270e+04
# 6    matMulStd      50    0.001027           3.783200e+03      4.025100e+05
# 7    matMulVec      50    0.000925           3.894400e+03      2.802196e+05
# 8   matMulIntr      50    0.000987           3.907600e+03      2.225471e+05
# 9    matMulStd     100    0.002429           1.270363e+05      2.505070e+06
# 10   matMulVec     100    0.001811           1.266087e+05      1.515490e+06
# 11  matMulIntr     100    0.001725           1.272415e+05      1.065153e+06
# 12   matMulStd     250    0.016825           1.967104e+06      3.422242e+07
# 13   matMulVec     250    0.011285           1.967608e+06      1.866068e+07
# 14  matMulIntr     250    0.010343           1.963722e+06      1.097110e+07
# 15   matMulStd     500    0.100060           1.569322e+07      2.617832e+08
# 16   matMulVec     500    0.067382           1.569293e+07      1.370337e+08
# 17  matMulIntr     500    0.059393           1.569648e+07      7.577927e+07
# 18   matMulStd    1000    0.856005           1.256780e+08      2.047025e+09
# 19   matMulVec    1000    0.623145           1.256756e+08      1.048020e+09
# 20  matMulIntr    1000    0.553508           1.258510e+08      5.530254e+08
# 21   matMulStd    2500   12.987243           3.897413e+09      3.154370e+10
# 22   matMulVec    2500    9.946191           3.899936e+09      1.592480e+10
# 23  matMulIntr    2500    8.707753           3.879426e+09      8.143651e+09
# 24   matMulStd    5000  102.724811           3.137930e+10      2.511745e+11
# 25   matMulVec    5000   78.920646           3.139940e+10      1.261982e+11
# 26  matMulIntr    5000   68.589793           3.136341e+10      6.382330e+10
# 27   matMulStd    7500  347.660170           1.058368e+11      8.463917e+11
# 28   matMulVec    7500  266.690440           1.058961e+11      4.245698e+11
# 29  matMulIntr    7500  232.113764           1.058125e+11      2.139120e+11
#
#     meanL1CacheLoadMissRate                  description
# 0                  0.059576  Standard (No Vectorization)
# 1                  0.062461       Vectorized By Compiler
# 2                  0.061675   Vectorized With Intrinsics
# 3                  0.027943  Standard (No Vectorization)
# 4                  0.033035       Vectorized By Compiler
# 5                  0.036333   Vectorized With Intrinsics
# 6                  0.009399  Standard (No Vectorization)
# 7                  0.013898       Vectorized By Compiler
# 8                  0.017559   Vectorized With Intrinsics
# 9                  0.050712  Standard (No Vectorization)
# 10                 0.083543       Vectorized By Compiler
# 11                 0.119458   Vectorized With Intrinsics
# 12                 0.057480  Standard (No Vectorization)
# 13                 0.105441       Vectorized By Compiler
# 14                 0.178990   Vectorized With Intrinsics
# 15                 0.059947  Standard (No Vectorization)
# 16                 0.114519       Vectorized By Compiler
# 17                 0.207134   Vectorized With Intrinsics
# 18                 0.061395  Standard (No Vectorization)
# 19                 0.119917       Vectorized By Compiler
# 20                 0.227568   Vectorized With Intrinsics
# 21                 0.123556  Standard (No Vectorization)
# 22                 0.244897       Vectorized By Compiler
# 23                 0.476374   Vectorized With Intrinsics
# 24                 0.124930  Standard (No Vectorization)
# 25                 0.248810       Vectorized By Compiler
# 26                 0.491410   Vectorized With Intrinsics
# 27                 0.125045  Standard (No Vectorization)
# 28                 0.249420       Vectorized By Compiler
# 29                 0.494654   Vectorized With Intrinsics

# %%
fig = px.line(df, x="runArg", y="meanTime", color="description", title="Mean Elapsed Time", labels={"runArg": "Matrix Size", "meanTime": "Time (s)", "description": "Program Used"}, markers=True)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="20aea6c5-3598-4ec4-878e-a5f138e29960" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20aea6c5-3598-4ec4-878e-a5f138e29960")) {                    Plotly.newPlot(                        "20aea6c5-3598-4ec4-878e-a5f138e29960",                        [{"hovertemplate":"Program Used=Standard (No Vectorization)<br>Matrix Size=%{x}<br>Time (s)=%{y}<extra></extra>","legendgroup":"Standard (No Vectorization)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Standard (No Vectorization)","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[0.0008631367,0.0009192188999990001,0.0010272454000000001,0.0024294859,0.016824885,0.1000595863,0.8560053269000001,12.9872426112,102.72481102510001,347.66017045139995],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized By Compiler<br>Matrix Size=%{x}<br>Time (s)=%{y}<extra></extra>","legendgroup":"Vectorized By Compiler","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized By Compiler","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[0.0007681042000000001,0.000744757299999,0.0009245468999990001,0.001810693499999,0.011284508199999,0.067382021,0.623144568999999,9.9461914566,78.92064558210001,266.6904401398],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized With Intrinsics<br>Matrix Size=%{x}<br>Time (s)=%{y}<extra></extra>","legendgroup":"Vectorized With Intrinsics","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized With Intrinsics","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[0.0007336569,0.0008053419000000001,0.000986681599999,0.001724709299999,0.010342959300000001,0.059393086799999,0.5535077449,8.7077530357,68.58979294369999,232.1137641034],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"t ...

# %%
# meanL1CacheLoadMisses

fig = px.line(df, x="runArg", y="meanL1CacheLoadMisses", color="description", title="Mean L1 Cache Load Misses", labels={"runArg": "Matrix Size", "meanL1CacheLoadMisses": "L1 Cache Load Misses", "description": "Program Used"}, markers=True)

fig.show()
# Out:
# <div>                            <div id="a2c84180-025f-411b-afe4-b6913ef61a37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2c84180-025f-411b-afe4-b6913ef61a37")) {                    Plotly.newPlot(                        "a2c84180-025f-411b-afe4-b6913ef61a37",                        [{"hovertemplate":"Program Used=Standard (No Vectorization)<br>Matrix Size=%{x}<br>L1 Cache Load Misses=%{y}<extra></extra>","legendgroup":"Standard (No Vectorization)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Standard (No Vectorization)","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[2481.5,2672.0,3783.2,127036.3,1967104.0,15693219.1,125677966.6,3897412875.0,31379295273.9,105836804219.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized By Compiler<br>Matrix Size=%{x}<br>L1 Cache Load Misses=%{y}<extra></extra>","legendgroup":"Vectorized By Compiler","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized By Compiler","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[2547.3,2688.0,3894.4,126608.7,1967608.4,15692926.6,125675620.3,3899936061.7,31399404121.2,105896088191.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized With Intrinsics<br>Matrix Size=%{x}<br>L1 Cache Load Misses=%{y}<extra></extra>","legendgroup":"Vectorized With Intrinsics","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized With Intrinsics","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[2495.7,2658.2,3907.6,127241.5,1963721.9,15696480.9,125850965.6,3879425524.9,31363413118.8,105812484238.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...

# %%
# meanL1CacheLoads 

fig = px.line(df, x="runArg", y="meanL1CacheLoads", color="description", title="Mean L1 Cache Loads", labels={"runArg": "Matrix Size", "meanL1CacheLoads": "L1 Cache Loads", "description": "Program Used"}, markers=True)

fig.show()
# Out:
# <div>                            <div id="388c1a26-7ad2-44e0-8abd-8754fd84421e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("388c1a26-7ad2-44e0-8abd-8754fd84421e")) {                    Plotly.newPlot(                        "388c1a26-7ad2-44e0-8abd-8754fd84421e",                        [{"hovertemplate":"Program Used=Standard (No Vectorization)<br>Matrix Size=%{x}<br>L1 Cache Loads=%{y}<extra></extra>","legendgroup":"Standard (No Vectorization)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Standard (No Vectorization)","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[41652.5,95623.6,402510.0,2505070.4,34222424.2,261783201.7,2047024992.0,31543698180.1,251174459018.3,846391665417.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized By Compiler<br>Matrix Size=%{x}<br>L1 Cache Loads=%{y}<extra></extra>","legendgroup":"Vectorized By Compiler","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized By Compiler","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[40782.5,81368.6,280219.6,1515490.0,18660677.0,137033731.9,1048020118.4,15924797601.1,126198242396.7,424569761915.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized With Intrinsics<br>Matrix Size=%{x}<br>L1 Cache Loads=%{y}<extra></extra>","legendgroup":"Vectorized With Intrinsics","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized With Intrinsics","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[40465.2,73162.7,222547.1,1065152.6,10971104.5,75779271.6,553025357.8,8143651184.3,63823298408.8,213911950457.7],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %%
# meanL1CacheLoadMissRate

fig = px.line(df, x="runArg", y="meanL1CacheLoadMissRate", color="description", title="Mean L1 Cache Load Miss Rate", labels={"runArg": "Matrix Size", "meanL1CacheLoadMissRate": "L1 Cache Load Miss Rate", "description": "Program Used"}, markers=True)

fig.show()
# Out:
# <div>                            <div id="04b3b787-8df5-4cac-8ade-fb8bb8ae43d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04b3b787-8df5-4cac-8ade-fb8bb8ae43d0")) {                    Plotly.newPlot(                        "04b3b787-8df5-4cac-8ade-fb8bb8ae43d0",                        [{"hovertemplate":"Program Used=Standard (No Vectorization)<br>Matrix Size=%{x}<br>L1 Cache Load Miss Rate=%{y}<extra></extra>","legendgroup":"Standard (No Vectorization)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Standard (No Vectorization)","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[0.05957625592701501,0.027942892758691003,0.009399021142331,0.05071166862216701,0.057479972444500003,0.05994738775478801,0.061395423647079006,0.12355599057369701,0.12493027912369702,0.125044714573623],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized By Compiler<br>Matrix Size=%{x}<br>L1 Cache Load Miss Rate=%{y}<extra></extra>","legendgroup":"Vectorized By Compiler","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized By Compiler","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[0.062460614234046,0.033034856197599,0.013897671683208001,0.083543078476268,0.10544142637483,0.114518712892179,0.11991718297533001,0.244897056740652,0.24881015396788903,0.24941976016764802],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized With Intrinsics<br>Matrix Size=%{x}<br>L1 Cache Load Miss Rate=%{y}<extra></extra>","legendgroup":"Vectorized With Intrinsics","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Vectorized With Intrinsics","orientation":"v","showlegend":true,"x":[10,25,50,100,250,500,1000,2500,5000,7500],"xaxis":"x","y":[0.061675217223688,0.036332721455058004,0.017558530306618,0.11945847008212701,0.178990355984668,0.207134227719338,0.22756816450632503,0.47637422540629804,0.49141009475742703,0.49465438472042605],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[ ...

# %%
# scatter plot of meanL1CacheLoadMissRate vs meanTime

fig = px.scatter(df, x="meanTime", y="meanL1CacheLoadMissRate", color="description", size="runArg",
 title="Mean L1 Cache Load Miss Rate vs Mean Elapsed Time", labels={"meanTime": "Time (s)", "meanL1CacheLoadMissRate": "L1 Cache Load Miss Rate", "description": "Program Used", "runArg": "Matrix Size"}, log_x=True)

fig.show()
# Out:
# <div>                            <div id="01280ffd-acd6-4724-aaa3-2ad7339dcdee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01280ffd-acd6-4724-aaa3-2ad7339dcdee")) {                    Plotly.newPlot(                        "01280ffd-acd6-4724-aaa3-2ad7339dcdee",                        [{"hovertemplate":"Program Used=Standard (No Vectorization)<br>Time (s)=%{x}<br>L1 Cache Load Miss Rate=%{y}<br>Matrix Size=%{marker.size}<extra></extra>","legendgroup":"Standard (No Vectorization)","marker":{"color":"#636efa","size":[10,25,50,100,250,500,1000,2500,5000,7500],"sizemode":"area","sizeref":18.75,"symbol":"circle"},"mode":"markers","name":"Standard (No Vectorization)","orientation":"v","showlegend":true,"x":[0.0008631367,0.0009192188999990001,0.0010272454000000001,0.0024294859,0.016824885,0.1000595863,0.8560053269000001,12.9872426112,102.72481102510001,347.66017045139995],"xaxis":"x","y":[0.05957625592701501,0.027942892758691003,0.009399021142331,0.05071166862216701,0.057479972444500003,0.05994738775478801,0.061395423647079006,0.12355599057369701,0.12493027912369702,0.125044714573623],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized By Compiler<br>Time (s)=%{x}<br>L1 Cache Load Miss Rate=%{y}<br>Matrix Size=%{marker.size}<extra></extra>","legendgroup":"Vectorized By Compiler","marker":{"color":"#EF553B","size":[10,25,50,100,250,500,1000,2500,5000,7500],"sizemode":"area","sizeref":18.75,"symbol":"circle"},"mode":"markers","name":"Vectorized By Compiler","orientation":"v","showlegend":true,"x":[0.0007681042000000001,0.000744757299999,0.0009245468999990001,0.001810693499999,0.011284508199999,0.067382021,0.623144568999999,9.9461914566,78.92064558210001,266.6904401398],"xaxis":"x","y":[0.062460614234046,0.033034856197599,0.013897671683208001,0.083543078476268,0.10544142637483,0.114518712892179,0.11991718297533001,0.244897056740652,0.24881015396788903,0.24941976016764802],"yaxis":"y","type":"scatter"},{"hovertemplate":"Program Used=Vectorized With Intrinsics<br>Time (s)=%{x}<br>L1 Cache Load Miss Rate=%{y}<br>Matrix Size=%{marker.size}<extra></extra>","legendgroup":"Vectorized With Intrinsics","marker":{"color":"#00cc96","size":[10,25,50,100,250,500,1000,2500,5000,7500],"sizemode":"area","sizeref":18.75,"symbol":"circle"},"mode":"markers","name":"Vectorized With Intrinsics","orientation":"v","showlegend":true,"x":[0.0007336569,0.0008053419000000001,0.000986681599999,0.001724709299999,0.010342959300000001,0.059393086799999,0.5535077449,8.7077530357,68.58979294369999,232.1137641034],"xaxis":"x","y":[0.061675217223688,0.036332721455058004,0.017558530306618,0.11945847008212701,0.178990355984668,0.207134227719338,0.22756816450632503,0.47637422540629804,0.49141009475742703,0.49465438472042605],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"# ...
